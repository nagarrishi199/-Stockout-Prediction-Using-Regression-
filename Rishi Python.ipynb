# %%
import pandas as pd
import numpy as np

# %%
pwd
# Out:
# 'c:\\Users\\Rishi Nagar\\Desktop\\Python Project'

# %%
cd "C:\Users\Rishi Nagar\Desktop"
# Out:
# C:\Users\Rishi Nagar\Desktop
# c:\Users\Rishi Nagar\Desktop\Python Project\my_env\Lib\site-packages\IPython\core\magics\osm.py:417: UserWarning: This is now an optional IPython functionality, setting dhist requires you to install the `pickleshare` library.
#   self.shell.db['dhist'] = compress_dhist(dhist)[-100:]

# %%
data= pd.read_csv("Sale Incentive June2024 BI (Temp).csv")

# %%
print(data)
# Out:
#           Location  Total TGT  Total Sale Total Achv.  Total Inc.  \
# 0      Bandundu P1    95000.0     86328.0         91%         0.0
# 1        Bukavu P1   230000.0    189221.0         82%         0.0
# 2         Bumba P1   170000.0    170265.0        100%       250.0
# 3         Bunia P1   180000.0    182162.0        101%       260.0
# 4       Butembo P1   240000.0    276078.0        115%       400.0
# 5      Fungrume P1   130000.0    110398.0         85%         0.0
# 6        Gemena P1    70000.0     50121.0         72%         0.0
# 7          Goma P1   320000.0    320105.0        100%       250.0
# 8       Kalemie P1   135000.0     96376.0         71%         0.0
# 9       Kananga P1   185000.0    171194.0         93%         0.0
# 10  Kasumbalesa P1   190000.0    154870.0         82%         0.0
# 11        Kenge P1    35000.0     34117.0         97%       190.0
# 12       Kikwit P1   245000.0    201234.0         82%         0.0
# ...

# %%
data.describe()
# Out:
#            Total TGT     Total Sale  Total Inc.    Branded TGT   Branded Sale  \
# count      52.000000      52.000000   53.000000      52.000000      52.000000
# mean   246057.692308  230490.019231   93.962264   31630.403846   29829.038462
# std    158940.538081  165923.713295  128.442439   37530.254821   33350.470117
# min     35000.000000   34117.000000    0.000000    1460.000000    1941.000000
# 25%    155000.000000  133677.500000    0.000000   13790.000000   12151.000000
# 50%    220000.000000  189628.000000    0.000000   23316.500000   23253.000000
# 75%    263750.000000  239630.500000  230.000000   36162.000000   34642.750000
# max    750000.000000  832436.000000  410.000000  261328.000000  204365.000000
#
#        Branded Inc.   Imported TGT  Imported Sale  Imported Inc.  Gross Total  \
# count     53.000000      52.000000      52.000000      53.000000    53.000000
# mean      40.943396  153912.923077  112983.961538       5.094340   140.000000
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 54 entries, 0 to 53
# Data columns (total 16 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Location          53 non-null     object
#  1   Total TGT         52 non-null     float64
#  2   Total Sale        52 non-null     float64
#  3   Total Achv.       52 non-null     object
#  4   Total Inc.        53 non-null     float64
#  5   Branded TGT       52 non-null     float64
#  6   Branded Sale      52 non-null     float64
#  7   Branded Achv.     52 non-null     object
#  8   Branded Inc.      53 non-null     float64
#  9   Imported TGT      52 non-null     float64
#  10  Imported Sale     52 non-null     float64
#  11  Imported Achv.    52 non-null     object
#  12  Imported Inc.     53 non-null     float64
#  13  Gross Total       53 non-null     float64
#  14  Asst.Manger Inc.  53 non-null     float64
#  15  Overall Inc.      53 non-null     float64
# ...

# %%
from itertools import groupby


df= data.groupby(by="Location")
print(df)

# %%
import matplotlib.pyplot as plt

# %%
pip install matplotlib
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.0 -> 24.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
data
# Out:
#           Location  Total TGT  Total Sale Total Achv.  Total Inc.  \
# 0      Bandundu P1    95000.0     86328.0         91%         0.0
# 1        Bukavu P1   230000.0    189221.0         82%         0.0
# 2         Bumba P1   170000.0    170265.0        100%       250.0
# 3         Bunia P1   180000.0    182162.0        101%       260.0
# 4       Butembo P1   240000.0    276078.0        115%       400.0
# 5      Fungrume P1   130000.0    110398.0         85%         0.0
# 6        Gemena P1    70000.0     50121.0         72%         0.0
# 7          Goma P1   320000.0    320105.0        100%       250.0
# 8       Kalemie P1   135000.0     96376.0         71%         0.0
# 9       Kananga P1   185000.0    171194.0         93%         0.0
# 10  Kasumbalesa P1   190000.0    154870.0         82%         0.0
# 11        Kenge P1    35000.0     34117.0         97%       190.0
# 12       Kikwit P1   245000.0    201234.0         82%         0.0
# ...

# %%
x= ["A","B","C"]
y= ["50","20","30"]

# %%
plt.bar(x,y,color="blue")
plt.xlabel("Value")
plt.ylabel("ABC")
plt.title("Bar Chart")
plt.show()

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 54 entries, 0 to 53
# Data columns (total 16 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Location          53 non-null     object
#  1   Total TGT         52 non-null     float64
#  2   Total Sale        52 non-null     float64
#  3   Total Achv.       52 non-null     object
#  4   Total Inc.        53 non-null     float64
#  5   Branded TGT       52 non-null     float64
#  6   Branded Sale      52 non-null     float64
#  7   Branded Achv.     52 non-null     object
#  8   Branded Inc.      53 non-null     float64
#  9   Imported TGT      52 non-null     float64
#  10  Imported Sale     52 non-null     float64
#  11  Imported Achv.    52 non-null     object
#  12  Imported Inc.     53 non-null     float64
#  13  Gross Total       53 non-null     float64
#  14  Asst.Manger Inc.  53 non-null     float64
#  15  Overall Inc.      53 non-null     float64
# ...

# %%
data["Location"]=data["Location"].astype(str)

# %%
data["Total TGT"]=data["Total TGT"].astype("Float64")

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 54 entries, 0 to 53
# Data columns (total 16 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Location          54 non-null     object
#  1   Total TGT         52 non-null     Float64
#  2   Total Sale        52 non-null     float64
#  3   Total Achv.       52 non-null     object
#  4   Total Inc.        53 non-null     float64
#  5   Branded TGT       52 non-null     float64
#  6   Branded Sale      52 non-null     float64
#  7   Branded Achv.     52 non-null     object
#  8   Branded Inc.      53 non-null     float64
#  9   Imported TGT      52 non-null     float64
#  10  Imported Sale     52 non-null     float64
#  11  Imported Achv.    52 non-null     object
#  12  Imported Inc.     53 non-null     float64
#  13  Gross Total       53 non-null     float64
#  14  Asst.Manger Inc.  53 non-null     float64
#  15  Overall Inc.      53 non-null     float64
# ...

# %%
Y=data["Location"]
TGT=data["Total TGT"]

# %%
plt.bar(Y,TGT,color="blue")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 plt.bar(Y,TGT,color="blue")
#
# File c:\Users\Rishi Nagar\Desktop\Python Project\my_env\Lib\site-packages\matplotlib\pyplot.py:2956, in bar(x, height, width, bottom, align, data, **kwargs)
#    2945 @_copy_docstring_and_deprecators(Axes.bar)
#    2946 def bar(
#    2947     x: float | ArrayLike,
#    (...)
#    2954     **kwargs,
#    2955 ) -> BarContainer:
# -> 2956     return gca().bar(
#    2957         x,
#    2958         height,
#    2959         width=width,
#    2960         bottom=bottom,
#    2961         align=align,
#    2962         **({"data": data} if data is not None else {}),
#    2963         **kwargs,
#    2964     )
#
# ...

# %%
A=data["Total Sale"]
B=data["Total TGT"]

# %%
plt.scatter(A,B,color="blue")

# %%
H=data["Location"]
J=data["Total TGT"]

plt.bar(H,J,color="red")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[28], line 4
#       1 H=data["Location"]
#       2 J=data["Total TGT"]
# ----> 4 plt.bar(H,J,color="red")
#
# File c:\Users\Rishi Nagar\Desktop\Python Project\my_env\Lib\site-packages\matplotlib\pyplot.py:2956, in bar(x, height, width, bottom, align, data, **kwargs)
#    2945 @_copy_docstring_and_deprecators(Axes.bar)
#    2946 def bar(
#    2947     x: float | ArrayLike,
#    (...)
#    2954     **kwargs,
#    2955 ) -> BarContainer:
# -> 2956     return gca().bar(
#    2957         x,
#    2958         height,
#    2959         width=width,
#    2960         bottom=bottom,
#    2961         align=align,
#    2962         **({"data": data} if data is not None else {}),
#    2963         **kwargs,
#    2964     )
#
# ...

# %%
print(data)
# Out:
#           Location  Total TGT  Total Sale Total Achv.  Total Inc.  \
# 0      Bandundu P1    95000.0     86328.0         91%         0.0
# 1        Bukavu P1   230000.0    189221.0         82%         0.0
# 2         Bumba P1   170000.0    170265.0        100%       250.0
# 3         Bunia P1   180000.0    182162.0        101%       260.0
# 4       Butembo P1   240000.0    276078.0        115%       400.0
# 5      Fungrume P1   130000.0    110398.0         85%         0.0
# 6        Gemena P1    70000.0     50121.0         72%         0.0
# 7          Goma P1   320000.0    320105.0        100%       250.0
# 8       Kalemie P1   135000.0     96376.0         71%         0.0
# 9       Kananga P1   185000.0    171194.0         93%         0.0
# 10  Kasumbalesa P1   190000.0    154870.0         82%         0.0
# 11        Kenge P1    35000.0     34117.0         97%       190.0
# 12       Kikwit P1   245000.0    201234.0         82%         0.0
# ...

# %%
data.head(5)
# Out:
#       Location  Total TGT  Total Sale Total Achv.  Total Inc.  Branded TGT  \
# 0  Bandundu P1    95000.0     86328.0         91%         0.0       7680.0
# 1    Bukavu P1   230000.0    189221.0         82%         0.0      13621.0
# 2     Bumba P1   170000.0    170265.0        100%       250.0      12474.0
# 3     Bunia P1   180000.0    182162.0        101%       260.0      15979.0
# 4   Butembo P1   240000.0    276078.0        115%       400.0      23052.0
#
#    Branded Sale Branded Achv.  Branded Inc.  Imported TGT  Imported Sale  \
# 0        7747.0          101%         100.0       59661.0        48490.0
# 1       11421.0           84%           0.0      195625.0       146671.0
# 2       10491.0           84%           0.0      144797.0       134758.0
# 3       14634.0           92%           0.0      118386.0       111916.0
# 4       24476.0          106%         100.0      180459.0       174848.0
#
# ...

# %%
data["Location"].head(5)
# Out:
# 0    Bandundu P1
# 1      Bukavu P1
# 2       Bumba P1
# 3       Bunia P1
# 4     Butembo P1
# Name: Location, dtype: object

# %%
data["Total TGT"].count()
# Out:
# np.int64(52)

# %%
data.value_counts()
# Out:
# Location        Total TGT  Total Sale  Total Achv.  Total Inc.  Branded TGT  Branded Sale  Branded Achv.  Branded Inc.  Imported TGT  Imported Sale  Imported Achv.  Imported Inc.  Gross Total  Asst.Manger Inc.  Overall Inc.
# Bandundu P1     95000.0    86328.0     91%          0.0         7680.0       7747.0        101%           100.0         59661.0       48490.0        81%             0.0            100.0        30.0              130.0           1
# Bukavu P1       230000.0   189221.0    82%          0.0         13621.0      11421.0       84%            0.0           195625.0      146671.0       75%             0.0            0.0          0.0               0.0             1
# Bumba P1        170000.0   170265.0    100%         250.0       12474.0      10491.0       84%            0.0           144797.0      134758.0       93%             0.0            250.0        75.0              325.0           1
# ...
